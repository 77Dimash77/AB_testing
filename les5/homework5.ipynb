# %% [markdown]
# 1)Вы провели эксперимент c упрощением формы заказа в магазине Утконос и получили результаты по метрике конверсий в покупку. Выберите метод оценки и оцените есть ли стат.значимые различия между конверсиями в двух группах при alpha = 5%. Дайте краткие рекомендации команде .Результаты: 1)Число юзеров в группах , которые заходили на сайт в период эксперимента: n1 = 15550 и n2 = 15550 . 2) Число юзеров в группах , которые совершили хотя бы одну покупку за период эксперимента: n1 = 164 и n2 = 228 3) Конверсии : conv1 = 1.05% conv2 = 1.47% .
# 2) Сравниваем метрику конверсия в покупку. Размер выборки - 10000 элементов в каждой группе . Какой статистический критерий тут лучше всего подойдёт и почему ?

# %%
import numpy as np
from scipy.stats import norm

# Задание A

# Данные для первой группы
n1 = 15550
conv1 = 0.0105
success1 = int(n1 * conv1)

# Данные для второй группы
n2 = 15550
conv2 = 0.0147
success2 = int(n2 * conv2)

# Оценка стандартной ошибки разности двух долей
p_pool = (success1 + success2) / (n1 + n2)
se = np.sqrt(p_pool * (1 - p_pool) * (1/n1 + 1/n2))

# Z-статистика
z_stat = (conv1 - conv2) / se

# P-value
p_value = 2 * (1 - norm.cdf(np.abs(z_stat)))

# Вывод результатов
print('Задание A:')
print(f'Z-статистика: {z_stat}')
print(f'p-value: {p_value}')

# Проверка на статистическую значимость при уровне значимости alpha = 0.05
if p_value < 0.05:
    print("Статистически значимые различия между конверсиями обнаружены. Рекомендации: РАБОТАТЬ (ваш комментарий)")
else:
    print("Статистически значимых различий между конверсиями не обнаружено. Рекомендации: БОЛЬШЕ РАБОТАТЬ (ваш комментарий)")

# Задание B

# Данные для первой группы (новые данные, так как размер выборки изменился)
n1_b = 10000
conv1_b = 0.0105
success1_b = int(n1_b * conv1_b)

# Данные для второй группы (новые данные, так как размер выборки изменился)
n2_b = 10000
conv2_b = 0.0147
success2_b = int(n2_b * conv2_b)

# Оценка стандартной ошибки разности двух долей
p_pool_b = (success1_b + success2_b) / (n1_b + n2_b)
se_b = np.sqrt(p_pool_b * (1 - p_pool_b) * (1/n1_b + 1/n2_b))

# Z-статистика
z_stat_b = (conv1_b - conv2_b) / se_b

# P-value
p_value_b = 2 * (1 - norm.cdf(np.abs(z_stat_b)))

# Вывод результатов
print('\nЗадание B:')
print(f'Z-статистика: {z_stat_b}')
print(f'p-value: {p_value_b}')

# Проверка на статистическую значимость при уровне значимости alpha = 0.05
if p_value_b < 0.05:
    print("Статистически значимые различия между конверсиями обнаружены.")
else:
    print("Статистически значимых различий между конверсиями не обнаружено.")
# Out:
# Задание A:
# Z-статистика: -3.3238289211195275
# p-value: 0.0008879064684259586
# Статистически значимые различия между конверсиями обнаружены. Рекомендации: ... (ваш комментарий)
#
# Задание B:
# Z-статистика: -2.6625787314775473
# p-value: 0.007754442670538042
# Статистически значимые различия между конверсиями обнаружены.
